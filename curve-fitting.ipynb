# %%
x = [0, 3, 6, 9, 10, 12, 18, 20, 25, 30, 40, 50, 60, 71, 90, 100 ]
y = [100 , 71.6393 , 52.20063 , 37.01505 , 31.64063 , 25.41168 , 12.96 , 9.834496 , 5.764802 , 3.111696 , 1.048576 , 0.331776 , 0.104976 , 0.02856099, 0.01 , 0.0]

# %%
(y[1]-y[0])/(x[1]-x[0])
# Out:
# -9.453566666666665

# %%
t = 0
db = 100
for i in range(1,16):
    y0 = x[i-1]
    y1 = x[i]
    delta = (y[i]-y[i-1])/(x[i]-x[i-1])
    for n in range(x[i-1],x[i]):
        print(100-t,db)
        db = db+delta;
        t = t+1
# Out:
# 100 100
# 99 90.54643333333334
# 98 81.09286666666668
# 97 71.63930000000002
# 96 65.15974333333335
# 95 58.680186666666685
# 94 52.20063000000002
# 93 47.13877000000002
# 92 42.07691000000003
# 91 37.01505000000003
# 90 31.64063000000003
# 89 28.52615500000003
# 88 25.411680000000032
# 87 23.336400000000033
# 86 21.261120000000034
# 85 19.185840000000034
# 84 17.110560000000035
# 83 15.035280000000036
# 82 12.960000000000036
# 81 11.397248000000037
# 80 9.834496000000037
# 79 9.020557200000038
# 78 8.206618400000039
# 77 7.392679600000039
# 76 6.578740800000039
# 75 5.7648020000000395
# 74 5.23418080000004
# 73 4.703559600000039
# 72 4.172938400000039
# 71 3.6423172000000386
# 70 3.1116960000000384
# 69 2.9053840000000384
# 68 2.6990720000000383
# 67 2.4927600000000383
# 66 2.2864480000000382
# 65 2.080136000000038
# 64 1.8738240000000381
# 63 1.667512000000038
# 62 1.461200000000038
# 61 1.254888000000038
# 60 1.048576000000038
# 59 0.976896000000038
# 58 0.905216000000038
# ...
